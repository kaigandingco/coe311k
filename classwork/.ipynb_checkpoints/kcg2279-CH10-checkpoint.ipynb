# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.random.randint(0, 10, size=10)
X_sorted = X[np.argsort(X)]
X_smoothPlot = np.linspace(min(X), max(X), 100) # x-values for smooth polyfit plotting
Y = np.random.randint(0, 10, size=10)

# %%
# Part A: Linear Least Squares vs Polynomial Fit
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
Y_leastSquares = m * X_sorted + c

coefficients = np.polyfit(X, Y, 3)
polynomial = np.poly1d(coefficients)
Y_polyfit = polynomial(X_sorted) # for calculating MSE and R-squared
Y_polyfit_smooth = polynomial(X_smoothPlot) # for plotting

# Printing information for each method
print(f"Least Squares Slope: {m}")
print(f"Least Squares Intercept: {c}")
print("Polynomial Fit Coefficients: ", coefficients)

# MSE for each method
mseLeastSquares = np.mean((Y - Y_leastSquares)**2)
msePolyfit = np.mean((Y - Y_polyfit)**2)

print("\nMean Squared Error for Each Method")
print(f"Least Squares Method: {mseLeastSquares}")
print(f"Cubic Polynomial Fit Method: {msePolyfit}")

# R-squared for each method
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res_ls = np.sum((Y - Y_leastSquares)**2)
r_squared_ls = 1 - (ss_res_ls / ss_total)
ss_res_pf = np.sum((Y - Y_polyfit)**2)
r_squared_pf = 1 - (ss_res_pf / ss_total)

print("\nR-squared for Each Method")
print(f"Least Squares Method: {r_squared_ls}")
print(f"Cubic Polynomial Fit Method: {r_squared_pf}")

# Which method is the better fit?
if (mseLeastSquares < msePolyfit) and (r_squared_ls > r_squared_pf):
    print("\nThe Least Squares method is the better fit.")
elif (msePolyfit < mseLeastSquares) and (r_squared_pf > r_squared_ls):
    print("\nThe Polynomial Fit method is the better fit.")
else:
    print("Could not determine which method is the better fit.")

# Plotting
plt.figure()
plt.scatter(X, Y, color='dodgerblue', label="Part A Random Data Points")
plt.plot(X_sorted, Y_leastSquares, color='green', label="Least Squares Method")
plt.plot(X_smoothPlot, Y_polyfit_smooth, color='indianred', label="Cubic Polynomial Fit Method")
plt.title("Comparing the Least Squares and the Polynomial Fit Methods")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()
# Out:
# Least Squares Slope: -0.22292993630573227
# Least Squares Intercept: 4.880254777070065
# Polynomial Fit Coefficients:  [ 0.04477174 -0.62391066  2.00918838  3.83736822]
#
# Mean Squared Error for Each Method
# Least Squares Method: 5.255286624203823
# Cubic Polynomial Fit Method: 8.631693448393364
#
# R-squared for Each Method
# Least Squares Method: 0.07639953880424921
# Cubic Polynomial Fit Method: -0.5169935761675506
#
# The Least Squares method is the better fit.

# %%
# Part B: Polynomial Fit with Increasing Degrees

# Cranking the polynomial up 1 degree at a time
for d in range(3, len(X) - 1):
    coefficients = np.polyfit(X, Y, d)
    polynomial = np.poly1d(coefficients)
    Y_polyfit = polynomial(X_sorted) # for calculating MSE and R-squared
    Y_polyfit_smooth = polynomial(X_smoothPlot) # for plotting
    
    # MSE and R-squared
    msePolyfit = np.mean((Y - Y_polyfit)**2)
    ss_res_pf = np.sum((Y - Y_polyfit)**2)
    r_squared_pf = 1 - (ss_res_pf / ss_total)
    
    # Printing coefficients, MSE, and R-squared
    print(f"Polynomial Fit of Degree {d}")
    print("Coefficients: ", coefficients)
    print(f"Polyfit Mean Squared Error: {msePolyfit}")
    print(f"Polyfit R-Squared: {r_squared_pf}\n")
    
    # Plotting
    plt.figure()
    plt.scatter(X, Y, color='dodgerblue', label="Part A Random Data Points")
    plt.plot(X_sorted, Y_leastSquares, color='green', label="Least Squares Method")
    plt.plot(X_smoothPlot, Y_polyfit_smooth, color='indianred', label=f"Polynomial Fit of Degree {d}")
    plt.title(f"Least Squares Method vs. Polynomial Fit Method of Degree {d}")
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid()
    plt.show()
# Out:
# Polynomial Fit of Degree 3
# Coefficients:  [ 0.04477174 -0.62391066  2.00918838  3.83736822]
# Polyfit Mean Squared Error: 8.631693448393364
# Polyfit R-Squared: -0.5169935761675506
# Polynomial Fit of Degree 4
# Coefficients:  [-0.00989395  0.20049541 -1.37852179  3.13475678  3.65690837]
# Polyfit Mean Squared Error: 8.425518813252946
# Polyfit R-Squared: -0.48075901814638744
# Polynomial Fit of Degree 5
# Coefficients:  [ 0.01227812 -0.24979558  1.80862264 -5.58727882  6.48601367  3.50652409]
# Polyfit Mean Squared Error: 8.144782276994299
# Polyfit R-Squared: -0.43142043532412977
# Polynomial Fit of Degree 6
# Coefficients:  [-7.68760159e-04  3.09201230e-02 -4.18970694e-01  2.51073080e+00
#  -6.86540493e+00  7.22577167e+00  3.50354436e+00]
# Polyfit Mean Squared Error: 8.17719335931539
# Polyfit R-Squared: -0.437116583359471
# Polynomial Fit of Degree 7
# Coefficients:  [ 5.72916667e-03 -1.67807540e-01  1.96473214e+00 -1.16691468e+01
# ...

# %%
# Part B: Polynomial Fit with Decreasing Degrees

# Cranking the polynomial down 1 degree at a time
for d in range(2, 0, -1):
    coefficients = np.polyfit(X, Y, d)
    polynomial = np.poly1d(coefficients)
    Y_polyfit = polynomial(X_sorted) # for calculating MSE and R-squared
    Y_polyfit_smooth = polynomial(X_smoothPlot) # for plotting

    # MSE and R-squared
    msePolyfit = np.mean((Y - Y_polyfit)**2)
    ss_res_pf = np.sum((Y - Y_polyfit)**2)
    r_squared_pf = 1 - (ss_res_pf / ss_total)
    
    # Printing coefficients, MSE, and R-squared
    print(f"Polynomial Fit of Degree {d}")
    print("Coefficients: ", coefficients)
    print(f"Polyfit Mean Squared Error: {msePolyfit}")
    print(f"Polyfit R-Squared: {r_squared_pf}\n")
    
    # Plotting
    plt.figure()
    plt.scatter(X, Y, color='dodgerblue', label="Part A Random Data Points")
    plt.plot(X_sorted, Y_leastSquares, color='green', label="Least Squares Method")
    plt.plot(X_smoothPlot, Y_polyfit_smooth, color='indianred', label=f"Polynomial Fit of Degree {d}")
    plt.title(f"Least Squares Method vs. Polynomial Fit Method of Degree {d}")
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid()
    plt.show()
# Out:
# Polynomial Fit of Degree 2
# Coefficients:  [-0.09024117  0.45014272  4.33834795]
# Polyfit Mean Squared Error: 6.783454693734891
# Polyfit R-Squared: -0.19217129942616684
# Polynomial Fit of Degree 1
# Coefficients:  [-0.22292994  4.88025478]
# Polyfit Mean Squared Error: 5.255286624203822
# Polyfit R-Squared: 0.07639953880424932

# %%
# Part C: The Vandermonde

# Function that constructs the Vandermonde matrix and returns the coefficients
def create_vandermonde_matrix(X, Y, degree):
    V = np.vander(X, N=degree+1, increasing=True)
    VT_V = V.T @ V
    VT_y = V.T @ Y
    a = np.linalg.solve(VT_V, VT_y) # Solves for a (coefficients)
    return V, a

# %%
# Part C: The Vandermonde

d = 3 # Cubic polynomial
V, coefficients = create_vandermonde_matrix(X, Y, d)
Y_vander = V @ coefficients
V_smoothPlot = np.vander(X_smoothPlot, d + 1, increasing=True)
Y_vander_smooth = V_smoothPlot @ coefficients

# MSE and R-squared
mseVander = np.mean((Y - Y_vander)**2)
ss_res_v = np.sum((Y - Y_vander)**2)
r_squared_v = 1 - (ss_res_v / ss_total)
    
# Printing coefficients, MSE, and R-squared
print("Cubic Polynomial Fit Using Vandermonde Matrix")
print("Coefficients: ", coefficients)
print(f"Vandermonde Mean Squared Error: {mseVander}")
print(f"Vandermonde R-Squared: {r_squared_v}\n")

# Plotting
plt.figure()
plt.scatter(X, Y, color='dodgerblue', label="Part A Random Data Points")
plt.plot(X_smoothPlot, Y_vander_smooth, color='indianred', label="Vandermonde Cubic Polynomial Fit")
plt.title("Cubic Polynomial Fit Using Vandermonde Matrix")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()
# Out:
# Cubic Polynomial Fit Using Vandermonde Matrix
# Coefficients:  [ 3.83736822  2.00918838 -0.62391066  0.04477174]
# Vandermonde Mean Squared Error: 4.728801668312061
# Vandermonde R-Squared: 0.1689276505602706
