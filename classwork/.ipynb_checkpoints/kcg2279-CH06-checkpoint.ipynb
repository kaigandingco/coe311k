# %%
import numpy as np
import time

def jacobi(A, b, x0, tolerance, maxIterations):
    n = len(b)
    x = x0.copy()
    
    for k in range (maxIterations):
        xNew = np.zeros_like(x)
        for i in range(n): 
            s = sum(A[i][j] * x[j] for j in range(n) if j!= i)
            xNew[i] = (b[i] - s) / A[i][i]
            
        if np.linalg.norm(xNew - x, ord=np.inf) < tolerance:
            return xNew, k
        
        x = xNew
    return x, maxIterations

# %%
def gauss_seidel(A, b, x0, tolerance, maxIterations):
    n = len(b)
    x = x0.copy()
    
    for k in range (maxIterations):
        xNew = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * xNew[j] for j in range (i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            xNew[i] = (b[i] - s1 -s2) / A[i][i]
            
        if np.linalg.norm(xNew - x, ord=np.inf) < tolerance:
            return xNew, k
        
        x = xNew
    return x, maxIterations

# %%
# Challenge 6a, Jacobi

A = np.array([[10, -1, 2, 0, 0],
              [-1, 11, -1, 3, 0],
              [2, -1, 10, -1, 0],
              [0, 3, -1, 8, -2],
              [0, 0, 0, -2, 9]], dtype=float)
b = np.array([14, 30, 26, 25, 37], dtype=float)
x0 = np.zeros_like(b)
tolerance = 1e-6
maxIterations = 100

startTime = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tolerance, maxIterations)
endTime = time.perf_counter()
totalTime = endTime - startTime

print("Challenge 6a, Jacobi\n")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {duration:.6f} seconds")
# Out:
# Challenge 6a, Jacobi
#
# Solution: [0.99999995 2.00000025 2.99999986 4.00000008 4.99999983]
# Iterations: 18
# Time: 0.013716 seconds

# %%
# Challenge 6a, Gauss-Seidel

A = np.array([[10, -1, 2, 0, 0],
              [-1, 11, -1, 3, 0],
              [2, -1, 10, -1, 0],
              [0, 3, -1, 8, -2],
              [0, 0, 0, -2, 9]], dtype=float)
b = np.array([14, 30, 26, 25, 37], dtype=float)
x0 = np.zeros_like(b)
tolerance = 1e-6
maxIterations = 100

startTime = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tolerance, maxIterations)
endTime = time.perf_counter()
duration = endTime - startTime

print("Challenge 6a, Gauss-Seidel\n")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {duration:.6f} seconds")
# Out:
# Challenge 6a, Gauss-Seidel
#
# Solution: [1.00000003 2.00000002 2.99999999 3.99999998 5.        ]
# Iterations: 10
# Time: 0.002843 seconds

# %%
# Challenge 6b, Jacobi

A = np.array([[1, 2, 3, 0, 0],
              [2, 1, 2, 3, 0],
              [3, 2, 1, 2, 3],
              [0, 3, 2, 1, 2],
              [0, 0, 3, 2, 1]], dtype=float)
b = np.array([14, 22, 33, 26, 22], dtype=float)
x0 = np.zeros_like(b)
tolerance = 1e-6
maxIterations = 100

startTime = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tolerance, maxIterations)
endTime = time.perf_counter()
duration = endTime - startTime

print("Challenge 6b, Jacobi\n")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {duration:.6f} seconds")
# Out:
# Challenge 6b, Jacobi
#
# Solution: [-3.43010894e+85 -4.24934579e+85 -5.28966155e+85 -4.24934579e+85
#  -3.43010894e+85]
# Iterations: 100
# Time: 0.007942 seconds

# %%
# Challenge 6b, Gauss-Seidel

A = np.array([[1, 2, 3, 0, 0],
              [2, 1, 2, 3, 0],
              [3, 2, 1, 2, 3],
              [0, 3, 2, 1, 2],
              [0, 0, 3, 2, 1]], dtype=float)
b = np.array([14, 22, 33, 26, 22], dtype=float)
x0 = np.zeros_like(b)
tolerance = 1e-6
maxIterations = 100

startTime = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tolerance, maxIterations)
endTime = time.perf_counter()
duration = endTime - startTime

print("Challenge 6b, Gauss-Seidel\n")
print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {duration:.6f} seconds")
# Out:
# Challenge 6b, Gauss-Seidel
#
# Solution: [-8.70303388e+112  3.37515847e+113 -5.07312279e+113 -1.50300774e+113
#   1.82253839e+114]
# Iterations: 100
# Time: 0.007909 seconds

# %%
"""
6a, Jacobi: Converged; took 18 iterations and 0.013716 seconds.
6a, Gauss-Seidel: Converged; took 10 iterations and 0.002843 seconds.

6b, Jacobi: Took 100 iterations and 0.007942 seconds.
6b, Gauss-Seidel: Took 100 iterations and 0.007909 seconds.
"""
# Out:
# '\n6a, Jacobi: Converged; took 18 iterations and 0.013716 seconds.\n6a, Gauss-Seidel: Converged; took 10 iterations and 0.002843 seconds.\n\n6b, Jacobi: Took 100 iterations and 0.007942 seconds.\n6b, Gauss-Seidel: Took 100 iterations and 0.007909 seconds.\n'
